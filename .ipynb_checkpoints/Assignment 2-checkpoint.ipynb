# %% [markdown]
# # Assignment 1
#
# ![](https://media.giphy.com/media/xT9C25UNTwfZuk85WP/giphy-downsized-large.gif)
#
# Remember the rules of ~Fight~ Code Club:
# 1. ALWAYS DOCUMENT
# 2. Cite resources that you use (paste links)
# 3. Include the names people who you worked with
# 4. Be neat and organized

# %% [markdown]
# ## Scrape and Clean data
#
# Based on you proposal, scrape or collect your data:
#
# 1. One variable must be either: (40 pts)
#     1. scraped from the web OR;
#     2. collected from an API AND you must create one new variable that is "new" to the best of your knowledge (combination of other variables representing something new).
#
# 2. You must have at least 3 variables, but you may include as many as you want into you final dataset. Likely, you will want to include more to make graphs and regressions. (30pts)
#
# 3. You must *be able* to run a regression that makes some sense with this data (the regression doesn't have to be a complete model). Briefly describe one regression you would run with your variables. (**DO NOT** run a regression, yet). (15pts)
#
# 4. You must have one combined and cleaned dataset (15 pts)
#
# You must submit one python notebook on how you scraped/gathered data from an api, and how you combined and cleaned you data. I should be able to run your code and reproduce your final data set.
#
# The other variables that you choose to include do not have to be collected by API or webscraped, but you do have to combine the files and clean the dataset with python.
#
# Thus, you must submit:
# - Your finalized data set (only one) (note: you may add more variables in the future).
# - Your documented python notebook
# - Any associated data files needed to produce the final dataset.
#
# You will be evaluated on:
# - Completeness of the data
# - Quality of the code
# - The creativity of the new variable/webscraped data you gather
#
# Be sure to upload ALL associated files for your code to run. I will run your code from beginning to end - make it easy for me to replicate your code.

# %%
# installs required packages
# !pip install google-search-results
# Out:
# Requirement already satisfied: google-search-results in c:\users\fearo\anaconda3\lib\site-packages (2.4.2)
# Requirement already satisfied: requests in c:\users\fearo\anaconda3\lib\site-packages (from google-search-results) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\fearo\anaconda3\lib\site-packages (from requests->google-search-results) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fearo\anaconda3\lib\site-packages (from requests->google-search-results) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\fearo\anaconda3\lib\site-packages (from requests->google-search-results) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fearo\anaconda3\lib\site-packages (from requests->google-search-results) (2026.1.4)

# %%
#imports api from provider
from serpapi import EbaySearch
# imports needed commands
import re
#parameters for api search
params = {
    "engine": "ebay",
    "_nkw": "hockey cards",
    "ebay_domain": "ebay.com",
    "api_key": "12a13973b8d58a4cc7b569859b257ef029573e1b3f116a9ecfcebd95b1f016a5",
    "show_only": "Sold, AV",
    "buying_format": "BIN",
    "lh_sold": "1"
}

#displays results
search = EbaySearch(params)
results = search.get_dict()
for result in results["organic_results"]:
    # Check if 'price' exists and has a 'raw' key before trying to access it
    if 'price' in result and isinstance(result['price'], dict) and 'raw' in result['price']:
        print(f"Title: {result['title']}, Price: {result['price']['raw']}")
    # If 'price' exists but doesn't have 'raw', try to print the price directly
    elif 'price' in result:
        print(f"Title: {result['title']}, Price: {result['price']}")
    # If no price information is available
    else:
        print(f"Title: {result['title']}, Price: Not available")
    print(result.get("sold_date"))


#parameters for api search
params = {
    "engine": "ebay",
    "_nkw": "hockey card hobby boxes",
    "ebay_domain": "ebay.com",
    "api_key": "12a13973b8d58a4cc7b569859b257ef029573e1b3f116a9ecfcebd95b1f016a5",
    "show_only": "Sold, AV",
    "buying_format": "BIN",
    "lh_sold": "1",
    
}

#displays results
search = EbaySearch(params)
results = search.get_dict()
for result in results["organic_results"]:
    # Check if 'price' exists and has a 'raw' key before trying to access it
    if 'price' in result and isinstance(result['price'], dict) and 'raw' in result['price']:
        print(f"Title: {result['title']}, Price: {result['price']['raw']}")
    # If 'price' exists but doesn't have 'raw', try to print the price directly
    elif 'price' in result:
        print(f"Title: {result['title']}, Price: {result['price']}")
    # If no price information is available
    else:
        print(f"Title: {result['title']}, Price: Not available")
    print(result.get("sold_date"))
# Out:
# Title: Gavin McKenna Signed 2023 Upper Deck CHL Autograph Hockey Card PSA/DNA Auto, Price: $799.99
# May 5, 2026
# Title: 1967 Topps Hockey Card - #72 Henri Richard, PSA 8 NM/MT, Price: $332.49
# May 5, 2026
# Title: 1969 Topps #40 Bob Nevin - PSA 9, Price: $297.00
# Apr 28, 2026
# Title: 1997-98 Upper Deck Buffalo Sabres Hockey Card #225 Dominik Hasek Error Card Rare, Price: $20,000.00
# May 5, 2026
# Title: 1985-86 O-Pee-Chee OPC #9 Mario Lemieux RC Rookie Card Penguins SGC 6 (READ), Price: $280.00
# May 5, 2026
# Title: Igor Shesterkin 2019-20 UD Stature Rookie Patch Auto /33 NY Rangers RPA, Price: $289.00
# May 4, 2026
# Title: 1985/86 Topps #9 Mario Lemieux PSA MINT 9 *7868 for pavlai, Price: $995.00
# May 4, 2026
# Title: 2021-22 Upper Deck The Cup Hockey Cards; Autos & Parallels. You pick!, Price: {'from': {'raw': '$7.00', 'extracted': 7.0}, 'to': {'raw': '$45.00', 'extracted': 45.0}}
# May 3, 2026
# Title: 2025-26 Upper Deck Allure Rookie Gabe Perreault Purple Diamond Auto /10, Price: $275.00
# May 3, 2026
# Title: 2023-24 Stature Hockey Luke Hughes Rookie Autograph Black 3/3 Card #34, Price: $399.98
# May 3, 2026
# Title: 1953 Parkhurst Hy Buller #58 PSA 8 NM MT Low Pop, Price: $750.00
# May 3, 2026
# Title: 1997-98 Donruss Elite Wayne Gretzky Status Gold Die Cut Generations #143 /100, Price: $250.00
# May 2, 2026
# Title: SHARP 1954-55 Topps Detroit Red Wings Hockey #58 Terry Sawchuk card - $800.00 !!, Price: $369.00
# May 2, 2026
# Title: Gordie Howe Signed 1971-72 Topps Card #70 Detroit Red Wings CGC 5 JSA 9 Auto, Price: $349.99
# May 2, 2026
# Title: Alex Ovechkin 2017-18 Upper Deck SPX Patch Autograph Card #19 01/10, Price: $649.95
# May 2, 2026
# Title: 2024-25 o-pee-chee platinum Vincent Trocheck Golden Treasures 1/1, Price: $300.00
# May 2, 2026
# Title: 1980 Topps #250 WAYNE GRETZKY | PSA 7 NM | Oilers HOF Edmonton 2nd Year Card, Price: $299.99
# May 1, 2026
# Title: 2008 Upper Deck The Cup Hockey - Patrice Bergeron Quad Patch On Card Auto, Price: $250.00
# May 1, 2026
# Title: Patrick Kane 2018-19 Upper Deck Exquisite Patch Autograph Card #EMS-PK 24/25, Price: $329.95
# May 1, 2026
# Title: 1951-52 PARKHURST HOCKEY MAURICE RICHARD ROOKIE RC #4 GRADED CARD SGC 1 PR, Price: $1,699.99
# Apr 30, 2026
# Title: 1971 Ken Dryden Topps Hockey Rookie Card RC #45 PSA 7, Price: $350.00
# Apr 23, 2026
# Title: Mario Lemieux 1985 Topps #9 PSA 8 Rookie RC HOF Super Mario Penguins, Price: $399.00
# Apr 23, 2026
# Title: 1957-58 TOPPS JOHNNY BUCYK ROOKIE CARD #10 BOSTON BRUINS HOF NHL HOCKEY Beauty, Price: $775.00
# Apr 23, 2026
# Title: 2009-10 Upper Deck THE CUP Base GOLD #/25 WAYNE GRETZKY Investment GRAIL 📈, Price: $499.99
# Apr 22, 2026
# Title: 2005-06 SP Authentic Future Watch Henrik Lundqvist RC Rookie Auto /999 PSA 10, Price: $749.99
# Apr 22, 2026
# Title: 1988-89 Topps NHL Hockey #66 Brett Hull Rookie PSA 9 MINT St Louis Blues RC Card, Price: $299.00
# Apr 22, 2026
# Title: 2005-06 SP Authentic Future Watch #171 Henrik Lundqvist Rookie Auto /999 HOF, Price: $250.00
# Apr 22, 2026
# Title: Upper Deck 2007-08 Young Guns Rookie Patrick Kane #210 NHL Hockey Card, Price: $275.00
# Apr 22, 2026
# Title: 2005-06 SP Authentic Future Watch #171 Henrik Lundqvist Rookie Auto /999 HOF, Price: $250.00
# Apr 22, 2026
# Title: 1955-56 PARKHURST Hockey NHL #57 Howie Morenz HOF OTG SGC 4 VG-EX Canadiens Card, Price: $375.00
# Apr 22, 2026
# Title: 2016/17 Upper Deck The Cup Matthew Tkachuk Rookie Patch Auto /249, Price: $535.95
# Apr 22, 2026
# Title: 1964-65 Topps hockey # 68 Jacques Plante (HOF) PSA 7 NM 2nd series base set, Price: $250.00
# Apr 21, 2026
# Title: ✅ 2023-24 Upper Deck The Cup Dustin Wolf Rookie Patch Auto #/249 Flames 🔥, Price: $279.99
# Apr 21, 2026
# Title: 1979-80 TOPPS #18 WAYNE GRETZKY EDMONTON OILERS ROOKIE HOCKEY CARD SGC 3 VG, Price: $825.00
# Apr 20, 2026
# Title: 1985/86 Topps #9 Mario Lemieux PSA NM-MT 8 *7862, Price: $317.76
# Apr 17, 2026
# Title: 1986 Topps Patrick Roy Rookie Card PSA 9 MINT Graded Hockey #53, Price: $499.99
# Apr 19, 2026
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 46
#      44 search = EbaySearch(params)
#      45 results = search.get_dict()
# ---> 46 for result in results["organic_results"]:
#      47     # Check if 'price' exists and has a 'raw' key before trying to access it
#      48     if 'price' in result and isinstance(result['price'], dict) and 'raw' in result['price']:
#      49         print(f"Title: {result['title']}, Price: {result['price']['raw']}")
#
# KeyError: 'organic_results'

# %%
expensive = [item for item in result if get_price(item["price"]) > 100]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 expensive = [item for item in result if (item["price"]) > 100]
#
# TypeError: string indices must be integers, not 'str'

# %%
# Out:
# dict

# %% [markdown]
# In order to create this dataset of hockey cards/hockey card boxes, their prices, and the dates they sold at, I had to use SerpApi, a free api for search engines like eBay. In order to find the data, I used specific parameters for things like the search itself, the domain, and showing only sold listings as I didn't want current listings to gum up the works. It was easy to combine data as I just put it all into one set, as they are similar enough to each other. Cleaning the data was easy as well, as I was able to extract exactly what I needed (title, price, and date sold), and not need to clean much. One regression I would currently run is how the price of sold single cards affects the price of sold hobby boxes, using date to perhaps control for big events that could affect the prices of cards or boxes. I am excited to carry this project to completion.
