# %% [markdown]
# # Assignment 1
#
# ![](https://media.giphy.com/media/xT9C25UNTwfZuk85WP/giphy-downsized-large.gif)
#
# Remember the rules of ~Fight~ Code Club:
# 1. ALWAYS DOCUMENT
# 2. Cite resources that you use (paste links)
# 3. Include the names people who you worked with
# 4. Be neat and organized

# %% [markdown]
# ## Scrape and Clean data
#
# Based on you proposal, scrape or collect your data:
#
# 1. One variable must be either: (40 pts)
#     1. scraped from the web OR;
#     2. collected from an API AND you must create one new variable that is "new" to the best of your knowledge (combination of other variables representing something new).
#
# 2. You must have at least 3 variables, but you may include as many as you want into you final dataset. Likely, you will want to include more to make graphs and regressions. (30pts)
#
# 3. You must *be able* to run a regression that makes some sense with this data (the regression doesn't have to be a complete model). Briefly describe one regression you would run with your variables. (**DO NOT** run a regression, yet). (15pts)
#
# 4. You must have one combined and cleaned dataset (15 pts)
#
# You must submit one python notebook on how you scraped/gathered data from an api, and how you combined and cleaned you data. I should be able to run your code and reproduce your final data set.
#
# The other variables that you choose to include do not have to be collected by API or webscraped, but you do have to combine the files and clean the dataset with python.
#
# Thus, you must submit:
# - Your finalized data set (only one) (note: you may add more variables in the future).
# - Your documented python notebook
# - Any associated data files needed to produce the final dataset.
#
# You will be evaluated on:
# - Completeness of the data
# - Quality of the code
# - The creativity of the new variable/webscraped data you gather
#
# Be sure to upload ALL associated files for your code to run. I will run your code from beginning to end - make it easy for me to replicate your code.

# %%
# installs required packages
# !pip install google-search-results
# Out:
# Requirement already satisfied: google-search-results in c:\users\fearo\anaconda3\lib\site-packages (2.4.2)
# Requirement already satisfied: requests in c:\users\fearo\anaconda3\lib\site-packages (from google-search-results) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\fearo\anaconda3\lib\site-packages (from requests->google-search-results) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fearo\anaconda3\lib\site-packages (from requests->google-search-results) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\fearo\anaconda3\lib\site-packages (from requests->google-search-results) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fearo\anaconda3\lib\site-packages (from requests->google-search-results) (2026.1.4)

# %%
#imports api from provider
from serpapi import EbaySearch

#parameters for api search
params = {
    "engine": "ebay",
    "_nkw": "hockey cards",
    "ebay_domain": "ebay.com",
    "api_key": "12a13973b8d58a4cc7b569859b257ef029573e1b3f116a9ecfcebd95b1f016a5",
    "show_only": "Sold",
    "buying_format": "BIN",
    "lh_sold": "1"
}

#displays results
search = EbaySearch(params)
results = search.get_dict()
for result in results["organic_results"]:
    # Check if 'price' exists and has a 'raw' key before trying to access it
    if 'price' in result and isinstance(result['price'], dict) and 'raw' in result['price']:
        print(f"Title: {result['title']}, Price: {result['price']['raw']}")
    # If 'price' exists but doesn't have 'raw', try to print the price directly
    elif 'price' in result:
        print(f"Title: {result['title']}, Price: {result['price']}")
    # If no price information is available
    else:
        print(f"Title: {result['title']}, Price: Not available")
    print(result.get("sold_date"))


#parameters for api search
params = {
    "engine": "ebay",
    "_nkw": "hockey card hobby boxes",
    "ebay_domain": "ebay.com",
    "api_key": "12a13973b8d58a4cc7b569859b257ef029573e1b3f116a9ecfcebd95b1f016a5",
    "show_only": "Sold",
    "buying_format": "BIN",
    "lh_sold": "1"
}

#displays results
search = EbaySearch(params)
results = search.get_dict()
for result in results["organic_results"]:
    # Check if 'price' exists and has a 'raw' key before trying to access it
    if 'price' in result and isinstance(result['price'], dict) and 'raw' in result['price']:
        print(f"Title: {result['title']}, Price: {result['price']['raw']}")
    # If 'price' exists but doesn't have 'raw', try to print the price directly
    elif 'price' in result:
        print(f"Title: {result['title']}, Price: {result['price']}")
    # If no price information is available
    else:
        print(f"Title: {result['title']}, Price: Not available")
    print(result.get("sold_date"))
# Out:
# Title: 1993/94 UPPER DECK SERIES TWO HOBBY SEALED HOCKEY BOX 36 PACKS, 12 CARD PACKS, Price: $49.95
# Apr 6, 2026
# Title: Jason Robertson Dallas Stars 2025-26 SP Hockey Upper Deck Card #63 Blue, Price: $1.50
# Apr 6, 2026
# Title: 2024-25 UD Synergy Rookie Red Parallel U-Pick, Price: $0.99
# Mar 22, 2026
# Title: 2025-26 Upper Deck Series 1 Hockey - Alexander Wennberg #141 Outburst, Price: $3.99
# Apr 6, 2026
# Title: Ben Scrivens 2014 Edmonton Oilers Card, Price: $1.43
# Apr 6, 2026
# Title: 1975-76 O-Pee-Chee Checklist (331-396) #267 VIEW SCAN CARD CONDITION, Price: $3.91
# Apr 6, 2026
# Title: 2021-22 Upper Deck Series 2 - Young Guns Nils Lundkvist #456 (RC), Price: $0.99
# Apr 6, 2026
# Title: Sidney Crosby #P-25 2015-16 Upper Deck Portraits Card Pittsburgh Penguins, Price: $2.01
# Apr 6, 2026
# Title: TEAM LOT - VANCOUVER CANUCKS HOCKEY 12 Cards NHL 2025 O-Pee-Chee, Price: $10.04
# Apr 6, 2026
# Title: 2006-07 Parkhurst Captains Barry Beck Auto #197 New York Rangers Autograph, Price: $1.99
# Apr 6, 2026
# Title: 2003-04 Upper Deck VICTORY Hockey Cards - You Pick your Card, Price: {'from': {'raw': '$0.71', 'extracted': 0.71}, 'to': {'raw': '$1.79', 'extracted': 1.79}}
# Sep 16, 2025
# Title: Vancouver Canucks Hockey Team 16 Card Lot, Price: $8.60
# Apr 6, 2026
# Title: 2012-13 SP Authentic Markus Naslund #136 New York Rangers, Price: $1.33
# Apr 6, 2026
# Title: 1966-67 Topps #8 Henri Richard Hockey Card Montreal Canadiens OPC Vintage, Price: $35.86
# Apr 6, 2026
# Title: Value Lot 5 Cards As Pictured, Price: $59.48
# Apr 6, 2026
# Title: 1980-81 O-Pee-Chee Giant Photo Hockey Complete 24 Card Set OPC Wayne Gretzky, Price: $71.70
# Apr 6, 2026
# Title: UPPERDECK OVERTIME 2017-18 CASEY CIZIKAS HOCKEY CARD #153 NUMBERED 29/99, Price: $3.59
# Apr 6, 2026
# Title: UPPERDECK SERIES ONE 2017-18 BROCK NELSON GAME JERSEY HOCKEY CARD GJ-BN, Price: $3.59
# Apr 6, 2026
# Title: UD SP GAME USED 2017-18 BROCK NELSON HOCKEY CARD #26 NUMBERED 074/126, Price: $3.59
# Apr 6, 2026
# Title: Huge Lot of 320 Edmonton Oilers Team Hockey Cards with Rookies Included., Price: $30.00
# Apr 6, 2026
# Title: 2024-25 Upper Deck Ice Rookie Emerald Green #118 Collin Graf Rookie Card, Price: $3.00
# Apr 6, 2026
# Title: 1998/99 Pacific Revolution NHL Hockey Trading Cards, Price: $3.00
# Apr 6, 2026
# Title: 1989-90 TOPPS 12 CARD ALL-STAR HOCKEY CARD STICKER SET NM-MT, Price: $12.00
# Apr 6, 2026
# Title: 1989-90 Topps Hockey Sticker Set #13-33 with Top/Bottom Logo Variations 28 Cards, Price: $19.99
# Apr 6, 2026
# Title: 1991-1992 O-Pee-Chee NHL Hockey Cards Complete 528 card set, Price: $8.61
# Apr 6, 2026
# Title: 2019-20 Upper Deck Allure Purple Diamond 2/10 Matthew Tkachuk #26 12kg, Price: $35.04
# Apr 6, 2026
# Title: 2019-20 Upper Deck Allure Green Quartz 54/99 Matthew Tkachuk #26 PSA 9 MINT 09gn, Price: $35.89
# Apr 6, 2026
# Title: 2003-04 Topps - Bash Masters Darius Kasparaitis #279 New York Rangers, Price: $0.99
# Apr 6, 2026
# Title: 1990-91 Pro Set Hockey Card Shayne Corson Montreal Canadiens #148, Price: $1.55
# Apr 6, 2026
# Title: Boston Bruins Hockey Card Lot - 160 Different Cards 2010/11 thru 2025/26, Price: $30.00
# Apr 6, 2026
# Title: Lot of 22 Different Tyler Seguin Hockey Card Collection Mint (includes RC), Price: $14.99
# Apr 6, 2026
# Title: 2026 Topps Now Jack Hughes Golden Goal USA Winter Olympics Hockey Card #18, Price: $4.00
# Apr 6, 2026
# Title: ALEXANDER YAKUSHEV CUSTOM HOCKEY HALL OF FAME HOF CARD-RARE CCCP, Price: $10.95
# Apr 6, 2026
# Title: 2023-24 Upper Deck Extended Series - Hockey Heroes 9 cards lot Marner Horton ++, Price: $13.62
# Apr 6, 2026
# Title: Sidney Crosby #P-25 2015-16 Upper Deck Portraits Card Pittsburgh Penguins, Price: $2.01
# Apr 6, 2026
# Title: 2023-24 Upper Deck National Hockey Card Day #NHCD31 Connor Bedard RM, Price: $1.12
# Apr 5, 2026
# Title: 2008-09 Upper Deck "Hockey Heroes" Complete (8 Card) Base Set...Sidney Crosby!, Price: $10.03
# Apr 6, 2026
# Title: Paul Coffey 1982 Topps Stickers #160 Edmonton Oilers Hockey Card EX, Price: $1.99
# Apr 6, 2026
# Title: 1982-83 O-Pee-Chee Hockey Card #102 IA Paul Coffey – Edmonton Oilers A1934, Price: $2.99
# Apr 6, 2026
# Title: 2025-26 O-Pee-Chee #226 Frank Nazar Chicago Blackhawks Hockey Card, Price: $1.33
# Apr 6, 2026
# Title: PETE STEMKOWSKI #16 2025-26 Upper Deck New York Rangers Centennial Auto, Price: $29.99
# Apr 6, 2026
# Title: 1989-90 Topps Hockey Complete 198 card set NM-MT, Price: $19.95
# Apr 6, 2026
# Title: 2025-26 SP Rookie Authentics Blue Gabe Perreault Rangers, Price: $2.60
# Apr 6, 2026
# Title: 2021-22 Upper Deck MVP Mascot Gaming Cards Howler The Coyote Arizona Coyotes #M2, Price: $1.50
# Apr 6, 2026
# Title: 2023-24 Skybox Metal Universe - Igor Shesterkin #112 Precious Metal Gems /100, Price: $39.99
# Apr 6, 2026
# Title: 2025-26 Upper Deck Artifacts Aurum Sean Monahan Unscratched Bounty Blue Jackets, Price: $6.45
# Apr 6, 2026
# Title: 1991-92 McDonald's Hockey Cards UD # 24 SCOTT STEVENS NEW JERSEY DEVILS, Price: $0.71
# Apr 6, 2026
# Title: Macklin Celebrini 2024-25 OPC Platinum Retro Rookie Card On Sale Now Bargain Too, Price: $47.71
# Apr 6, 2026
# Title: 1961 TOPPS #62 ROD GILBERT RC PSA, Price: $179.28
# Apr 6, 2026
# Title: 1983-84 O-Pee-Chee #374 Rod Langway Washington Capitals HOCKEY Card K3, Price: $3.49
# Apr 6, 2026
# Title: 1973-74 Topps Hockey Card Number 174 Red Berenson Detroit Red Wings #174, Price: $2.15
# Apr 6, 2026
# Title: 🔥2011-12 - Jarome Iginla - Pinnacle - Canvas Creations - Calgary Flames #18🔥, Price: $3.55
# Apr 6, 2026
# Title: 2023-24 Skybox Metal Universe hockey complete 200 card set w all SP + Bedard RC, Price: $43.03
# Apr 6, 2026
# Title: 1990-91 Score Eric Lindros Rookies Hockey Cards #440, Price: $4.00
# Apr 6, 2026
# Title: Hockey Card Lot (305) Gretzky Lemieux Jagr Sakic Hull Hasek Forsberg Brodeur..., Price: $12.91
# Apr 6, 2026
# Title: 1991 Impel US Olympic Hall of Fame 1980 USA Hockey Team Complete 11 card set, Price: $7.22
# Apr 6, 2026
# Title: Hockey card | Brandon Hagel #419 | O-Pee-Chee 2025-26 Blue Border, Price: $1.50
# Apr 6, 2026
# Title: DON BARBER Signed Upper Deck Hockey Trading Card-MINNESOTA NORTH STARS-PSA, Price: $16.24
# Apr 6, 2026
# Title: 1979-80 Topps Hockey #78 Ron Greschner, Price: $1.49
# Apr 6, 2026
# Title: 2025-26 Upper Deck Series 2 - Young Guns Matvei Gridin #466 (RC), Price: $5.99
# Apr 6, 2026
# Title: 1993/94 UPPER DECK SERIES TWO HOBBY SEALED HOCKEY BOX 36 PACKS, 12 CARD PACKS, Price: $49.95
# Apr 6, 2026
# Title: 2023-24 Upper Deck Series 2 Hockey HOBBY pack 12 cards Young guns ONE PACK ONLY, Price: $28.68
# Apr 5, 2026
# Title: 2023-24 Upper Deck Premier NHL Hockey Hobby Box 1 Pack 6 Premium Cards, Price: $349.99
# Apr 5, 2026
# Title: 2023-24 Upper Deck Series 2 Hockey HOBBY pack 12 cards Young guns, Price: $32.27
# Apr 5, 2026
# Title: 2025 President's Choice Exclusive Seventh Edition Hockey Hobby Box 4 Cards, Price: $272.49
# Apr 5, 2026
# Title: 2024-25 Upper Deck MVP Hockey Hobby Box Sealed 20x8 CARDS 💥, Price: $30.11
# Apr 4, 2026
# Title: 2023 Upper Deck Artifacts Hockey Hobby Box Factory Sealed 8 Packs /4 Cards🔥👀, Price: $144.95
# Apr 3, 2026
# Title: 2023-24 NHL UPPER DECK Allure Hockey Factory Sealed Hobby Box 64 Cards, Price: $199.99
# Apr 2, 2026
# Title: 2013-14 Panini Crown Royale Hockey Cards Hobby Box Mackinnon Auto Rookie? Sealed, Price: $199.00
# Apr 2, 2026
# Title: 1989–90 to 2008-09 Sealed Hockey Card Boxes ~ Upper Deck and O-Pee-Chee. NIB, Price: {'from': {'raw': '$82.47', 'extracted': 82.47}, 'to': {'raw': '$365.72', 'extracted': 365.72}}
# Apr 1, 2026
# Title: 2022-23 Upper Deck MVP NHL Hockey Hobby Box Factory Sealed 20 Packs 160 Cards, Price: $29.99
# Mar 31, 2026
# Title: 2013/14 PANINI CROWN ROYALE HOCKEY HOBBY BOX BLOWOUT CARDS, Price: $186.95
# Mar 31, 2026
# Title: 2000 Pacific Aurora NHL Hockey Card Hobby Box - Factory Sealed, Price: $200.00
# Mar 30, 2026
# Title: 2006/07 Upper Deck MVP Hockey MASSIVE Factory Sealed HOBBY Box-192 Card+DUAL MEM, Price: $149.95
# Mar 29, 2026
# Title: Factory Sealed Hobby Box 2022-2023 Upper Deck MVP Hockey Cards, Price: $32.99
# Mar 29, 2026
# Title: 2022-23 Upper Deck MVP NHL Hockey Hobby Box Factory Sealed 20 Packs 160 Cards, Price: $32.89
# Mar 28, 2026
# Title: 2023-24 NHL O-Pee-Chee Hockey Factory Sealed Hobby Box 180 Cards, Price: $169.99
# Mar 28, 2026
# Title: 2008-09 NHL Upper Deck Victory Hockey Cards Hobby Box Factory Sealed, Price: $53.78
# Mar 26, 2026
# Title: 2023-24 NHL UPPER DECK SERIES ONE 1 Hockey Factory Sealed Hobby Box 144 Cards, Price: $129.99
# Mar 26, 2026
# Title: Factory Sealed Hobby Box 2023-2024 Upper Deck MVP NHL Hockey Cards, Price: $64.99
# Mar 26, 2026
# Title: 95/96 Leaf limited Hockey hobby Box Donrus NHL Trading Cards, Price: $71.67
# Mar 25, 2026
# Title: 2023-24 NHL UPPER DECK SERIES 2 Hockey Factory Sealed Hobby Box 144 Cards, Price: $279.99
# Mar 25, 2026
# Title: 2025/26 Upper Deck MVP Hockey Hobby Box 20 Packs per Box, 8 Cards per Pack, Price: $75.29
# Mar 24, 2026
# Title: 2023/24 Upper Deck Clear Cut Hockey Hobby Box 1 Card per Box - Factory Sealed, Price: $121.90
# Mar 24, 2026
# Title: 2024-25 PWHL UPPER DECK Hockey Factory Sealed Hobby Box 72 Cards, Price: $169.99
# Mar 23, 2026
# Title: Upper Deck Credentials 2021-22 NHL Hockey Hobby Box, 6 Cards Per Pack, 8 Packs, Price: $61.00
# Mar 21, 2026
# Title: 2023-24 Upper Deck Engrained Hockey NHL Hobby Box Factory Sealed 6 Card Per Box, Price: $237.92
# Feb 8, 2026
# Title: 2023-24 Upper Deck Engrained Hockey NHL Hobby Box Factory Sealed 6 Cards Per Box, Price: $237.92
# Jan 23, 2026
# Title: 2022/23 Upper Deck MVP Hockey Factory Sealed Hobby Pack - 8 Cards, Price: $5.74
# Mar 19, 2026
# Title: Vintage 1994 Donruss NHL Hockey 36 Pack Cards Hobby Box Sealed, Price: $50.00
# Mar 17, 2026
# Title: 1994/95 Pinnacle Series 1 Hockey Hobby Box Factory Sealed 24 packs 14 cards per, Price: $119.95
# Mar 17, 2026
# Title: NHL 1993-94 Premier Hockey Series 1 Trading Card HOBBY Box [36 Packs], Price: $39.99
# Jun 15, 2025
# Title: Factory Sealed Hobby Box 2018-19 Upper Deck Artifacts NHL Hockey Cards, Price: $209.99
# Aug 20, 2025
# Title: 2022-23 Upper Deck MVP NHL Hockey Hobby Box Factory Sealed 20 Packs 160 Cards, Price: $32.99
# Mar 8, 2026
# Title: 2024-25 NHL UPPER DECK SERIES 2 Hockey Factory Sealed Hobby Box 144 Cards, Price: $375.00
# Mar 13, 2026
# Title: 2024/25 Upper Deck Series 2 Hockey Hobby Box FACTORY SEALED Steve's Cards NH., Price: $127.90
# Sep 10, 2025
# Title: NHL 1996/97 upperdeck hockey HOBBY series 2 wax box cards sealed 24packs, Price: $149.99
# Mar 13, 2026
# Title: 2015-16 UD MVP Hockey 2 Sealed Hobby Boxes 8 Cards Per Pack 24 Packs Per Box, Price: $225.00
# Mar 12, 2026
# Title: Swedish Hockey Trading Cards Rare Upper Deck 98/99 Hobby Box Factory Sealed New, Price: $37.95
# Mar 10, 2026
# Title: 2025/26 Upper Deck Series 2 Hockey Hobby Box 12 Packs Per Box, 12 Cards Per Pack, Price: $215.12
# Mar 9, 2026
# Title: 1995 DONRUSS NHL Hockey 36 Count Trading Card Hobby Box Still Factory SEALED, Price: $89.99
# Mar 8, 2026
# Title: 1997-98 Upper Deck Hockey Collector's Choice Hobby Pack 5 Cards UNSEALED, Price: $0.72
# Mar 7, 2026
# Title: 1997-98 Upper Deck Hockey Collector's Choice Hobby Pack 5 Cards New/Sealed, Price: $2.69
# Mar 7, 2026
# Title: 1991-1992 NHL Upper Deck Hockey Cards Pack Box Low Number box SEALED Hobby Box, Price: $25.00
# Mar 6, 2026
# Title: 1989 Topps Hockey Hobby Box Original Stock Mullen, Turgeon ++ Box Bottom Cards, Price: $79.00
# Mar 6, 2026
# Title: 1990/91 PRO SET SERIES ONE HOCKEY SEALED HOBBY BOX 36 PACK, 15 CARD PACKS (READ), Price: $32.95
# Mar 3, 2026
# Title: 2023-24 Upper Deck Premier NHL Hockey Hobby Box 1 Pack 6 Premium Cards, Price: $332.99
# Mar 2, 2026
# Title: 2019/20 Upper Deck MVP Hockey HUGE Factory Sealed HOBBY Box-160 Cards, Price: $69.95
# Feb 27, 2026
# Title: 2022/23 Upper Deck Clear Cut Hockey Hobby Box 1 AUTO CARD, Price: $99.95
# Feb 25, 2026
# Title: 2000 Pacific Aurora NHL Hockey Card Hobby Box - Factory Sealed, Price: $200.00
# Feb 23, 2026
# Title: Factory Sealed Hobby Box 2023-24 Upper Deck Synergy NHL Hockey Cards, Price: $86.99
# Feb 22, 2026
# Title: 1994-95 PINNACLE SELECT FACTORY SEALED HOCKEY HOBBY BOXES 3 TIER CHASE CARDS, Price: $64.99
# Feb 21, 2026
# Title: Upper Deck 2022-23 Black Diamond Ice Hockey Hobby Box - 6 Cards, Price: $215.00
# Feb 20, 2026
# Title: 1995-96 UPPER DECK HOCKEY SERIES 2 FACTORY SEALED HOBBY BOX 28 PACKS 12 CARDS, Price: $100.00
# Feb 19, 2026
# Title: 2023/24 Upper Deck Clear Cut Hockey Hobby Box 1 Card per Box - Factory Sealed, Price: $121.90
# Feb 19, 2026
# Title: 2024-25 NHL UPPER DECK Allure Hockey Factory Sealed Hobby Box 64 Cards, Price: $189.99
# Feb 18, 2026
# Title: 2022/23 Upper Deck MVP Hockey HUGE Factory Sealed HOBBY Box-160 Cards!, Price: $34.95
# Feb 15, 2026
# Title: 2021-22 Upper Deck Extended Hockey Card Sealed Hobby Box, Price: $103.97
# Feb 14, 2026
# Title: 1991 Topps Stadium Club NHL Hockey Premium Card Hobby Box Gretzky Hull Lemieux, Price: $19.99
# Feb 13, 2026
# Title: 2022-23 Upper Deck MVP NHL Hockey Hobby Box Factory Sealed 20 Packs 160 Cards, Price: $32.99
# Feb 12, 2026

# %% [markdown]
# In order to create this dataset of hockey cards/hockey card boxes, their prices, and the dates they sold at, I had to use SerpApi, a free api for search engines like eBay. In order to find the data, I used specific parameters for things like the search itself, the domain, and showing only sold listings as I didn't want current listings to gum up the works. It was easy to combine data as I just put it all into one set, as they are similar enough to each other. Cleaning the data was easy as well, as I was able to extract exactly what I needed (title, price, and date sold), and not need to clean much. One regression I would currently run is how the price of sold single cards affects the price of sold hobby boxes, using date to perhaps control for big events that could affect the prices of cards or boxes. I am excited to carry this project to completion.
